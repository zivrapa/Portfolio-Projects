# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pyspark.sql.functions import split, explode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 6
#       4 import seaborn as sns
#       5 import plotly.express as px
# ----> 6 from pyspark.sql.functions import split, explode
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
survey_data = pd.read_csv('C:/Users/lab_p/Downloads/סקר פוליטיקל - השינויים במערכת המשפט.csv')
survey_data.head()
# Out:
#                      Timestamp  \
# 0  2023/02/28 4:03:03 PM GMT+2
# 1  2023/02/28 4:07:27 PM GMT+2
# 2  2023/02/28 5:58:11 PM GMT+2
# 3  2023/02/28 6:03:54 PM GMT+2
# 4  2023/03/02 4:55:22 PM GMT+2
#
#                  סמן/י את כל המשפטים שרלוונטים אלייך
# 0  מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 1  דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# 2            דעה - לא יודע אם אני בעד או נגד הרפורמה
# 3  מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 4  מעקב - לא מצליח/ה לעקוב אחרי התקדמות הרפורמה ו...

# %%
survey_data['סמן/י את כל המשפטים שרלוונטים אלייך'].value_counts()
# Out:
# מעקב - לא מצליח/ה לעקוב אחרי התקדמות השינויים ומתי כל שינוי אמור לעבור בכנסת;פירוט - רוצה להכיר את החוקים ולקבל יותר מידע על השינויים המוצעים                                                                                                                                                                                                                       234
# פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה להציע פשרה משלי                                                                                                                                                                                                                                                                                                           5
# ...

# %%
survey_data['Timestamp'].value_counts()
# Out:
# 2023/03/02 7:08:24 PM GMT+2    57
# 2023/03/02 7:08:25 PM GMT+2    28
# 2023/02/28 4:03:03 PM GMT+2     1
# 2023/03/02 7:10:04 PM GMT+2     1
# 2023/03/02 7:09:57 PM GMT+2     1
#                                ..
# 2023/03/02 7:09:07 PM GMT+2     1
# 2023/03/02 7:09:08 PM GMT+2     1
# 2023/03/02 7:09:09 PM GMT+2     1
# 2023/03/02 7:09:10 PM GMT+2     1
# 2023/03/03 4:08:20 PM GMT+2     1
# Name: Timestamp, Length: 172, dtype: int64

# %%
survey_data = survey_data.assign(var=survey_data["סמן/י את כל המשפטים שרלוונטים אלייך"].str.split(';'))
survey_data
# Out:
#                         Timestamp  \
# 0     2023/02/28 4:03:03 PM GMT+2
# 1     2023/02/28 4:07:27 PM GMT+2
# 2     2023/02/28 5:58:11 PM GMT+2
# 3     2023/02/28 6:03:54 PM GMT+2
# 4     2023/03/02 4:55:22 PM GMT+2
# ..                            ...
# 250   2023/03/02 9:31:00 PM GMT+2
# 251  2023/03/03 10:14:39 AM GMT+2
# 252  2023/03/03 10:49:58 AM GMT+2
# 253   2023/03/03 1:32:19 PM GMT+2
# 254   2023/03/03 4:08:20 PM GMT+2
#
#                    סמן/י את כל המשפטים שרלוונטים אלייך  \
# 0    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 1    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# 2              דעה - לא יודע אם אני בעד או נגד הרפורמה
# 3    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 4    מעקב - לא מצליח/ה לעקוב אחרי התקדמות הרפורמה ו...
# ..                                                 ...
# 250  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# 251  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# ...

# %%
survey_data = survey_data.explode('var', ignore_index = True)

# %%
survey_data['var'].value_counts()
# Out:
# פירוט - רוצה להכיר את החוקים ולקבל יותר מידע על השינויים המוצעים                  238
# מעקב - לא מצליח/ה לעקוב אחרי התקדמות השינויים ומתי כל שינוי אמור לעבור בכנסת      236
# פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה להציע פשרה משלי                        12
# השפעה - רוצה לדעת איך השינויים ישפיעו עליי כאזרח/ית (בפן כלכלי, חברתי, דתי...)      5
# פירוט - רוצה להכיר את החוקים מהם בנויה הרפורמה                                      5
# השפעה - רוצה לדעת איך הרפורמה תשפיע עליי כאזרח/ית (בפן כלכלי, חברתי, דתי...)        3
# מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומתי היא אמורה לעבור                     3
# השפעה - רוצה לדעת איך הרפורמה תשפיע עליי כאזרח (בפן כלכלי, חברתי, דתי...)           3
# מעקב - לא מצליח/ה לעקוב אחרי התקדמות הרפורמה ומתי היא אמורה לעבור                   2
# דעה - לא יודע אם אני בעד או נגד הרפורמה                                             2
# טוויטר - אני לא מבין/ה את כל הציוצים ברשתות חברתיות ואשמח לקונטקס והסבר             2
# ...

# %%
# survey_data.assign(var1=survey_data['סמן/י את כל המשפטים שרלוונטים אלייך'].str.split(';'))

# %%
# survey_data['סמן/י את כל המשפטים שרלוונטים אלייך'] = survey_data['סמן/י את כל המשפטים שרלוונטים אלייך'].apply(lambda x: ' '.join(x.split(' ')[0:1]))
# survey_data['סמן/י את כל המשפטים שרלוונטים אלייך']

# %%
px.histogram(survey_data, x="var")
# Out:
# <div>                            <div id="e000416a-b56c-4627-ba34-5718275d83ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e000416a-b56c-4627-ba34-5718275d83ff")) {                    Plotly.newPlot(                        "e000416a-b56c-4627-ba34-5718275d83ff",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"var=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["\u05de\u05e2\u05e7\u05d1 - \u05dc\u05d0 \u05de\u05e6\u05dc\u05d9\u05d7 \u05dc\u05e2\u05e7\u05d5\u05d1 \u05d0\u05d7\u05e8\u05d9 \u05d4\u05ea\u05e7\u05d3\u05de\u05d5\u05ea \u05d4\u05e8\u05e4\u05d5\u05e8\u05de\u05d4 \u05d5\u05de\u05ea\
# ...

# %%
survey_data['Timestamp'].value_counts()
# Out:
# 2023/03/02 7:08:24 PM GMT+2     114
# 2023/03/02 7:08:25 PM GMT+2      56
# 2023/03/02 6:43:47 PM GMT+2       5
# 2023/03/02 4:55:34 PM GMT+2       5
# 2023/03/02 4:55:22 PM GMT+2       4
#                                ...
# 2023/03/02 9:31:00 PM GMT+2       1
# 2023/03/03 10:14:39 AM GMT+2      1
# 2023/03/03 10:49:58 AM GMT+2      1
# 2023/02/28 5:58:11 PM GMT+2       1
# 2023/03/02 5:37:14 PM GMT+2       1
# Name: Timestamp, Length: 172, dtype: int64

# %%
survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            517 non-null    object
#  1   סמן/י את כל המשפטים שרלוונטים אלייך  517 non-null    object
#  2   var                                  517 non-null    object
# dtypes: object(3)
# memory usage: 12.2+ KB

# %%
new_df = survey_data.copy()
new_df
# Out:
#                         Timestamp  \
# 0     2023/02/28 4:03:03 PM GMT+2
# 1     2023/02/28 4:03:03 PM GMT+2
# 2     2023/02/28 4:03:03 PM GMT+2
# 3     2023/02/28 4:07:27 PM GMT+2
# 4     2023/02/28 4:07:27 PM GMT+2
# ..                            ...
# 512  2023/03/03 10:49:58 AM GMT+2
# 513   2023/03/03 1:32:19 PM GMT+2
# 514   2023/03/03 1:32:19 PM GMT+2
# 515   2023/03/03 4:08:20 PM GMT+2
# 516   2023/03/03 4:08:20 PM GMT+2
#
#                    סמן/י את כל המשפטים שרלוונטים אלייך  \
# 0    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 1    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 2    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 3    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# 4    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# ..                                                 ...
# 512  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# 513  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# ...

# %%
new_df['Timestamp'].value_counts()
# Out:
# 2023/03/02 7:08:24 PM GMT+2     114
# 2023/03/02 7:08:25 PM GMT+2      56
# 2023/03/02 6:43:47 PM GMT+2       5
# 2023/03/02 4:55:34 PM GMT+2       5
# 2023/03/02 4:55:22 PM GMT+2       4
#                                ...
# 2023/03/02 9:31:00 PM GMT+2       1
# 2023/03/03 10:14:39 AM GMT+2      1
# 2023/03/03 10:49:58 AM GMT+2      1
# 2023/02/28 5:58:11 PM GMT+2       1
# 2023/03/02 5:37:14 PM GMT+2       1
# Name: Timestamp, Length: 172, dtype: int64

# %%
new_df.drop(new_df[new_df['Timestamp'] == '2023/03/02 7:08:24 PM GMT+2'].index, inplace = True)
new_df
# Out:
#                         Timestamp  \
# 0     2023/02/28 4:03:03 PM GMT+2
# 1     2023/02/28 4:03:03 PM GMT+2
# 2     2023/02/28 4:03:03 PM GMT+2
# 3     2023/02/28 4:07:27 PM GMT+2
# 4     2023/02/28 4:07:27 PM GMT+2
# ..                            ...
# 512  2023/03/03 10:49:58 AM GMT+2
# 513   2023/03/03 1:32:19 PM GMT+2
# 514   2023/03/03 1:32:19 PM GMT+2
# 515   2023/03/03 4:08:20 PM GMT+2
# 516   2023/03/03 4:08:20 PM GMT+2
#
#                    סמן/י את כל המשפטים שרלוונטים אלייך  \
# 0    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 1    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 2    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 3    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# 4    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# ..                                                 ...
# 512  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# 513  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# ...

# %%
new_df.drop(new_df[new_df['Timestamp'] == '2023/03/02 7:08:25 PM GMT+2'].index, inplace = True)
new_df
# Out:
#                         Timestamp  \
# 0     2023/02/28 4:03:03 PM GMT+2
# 1     2023/02/28 4:03:03 PM GMT+2
# 2     2023/02/28 4:03:03 PM GMT+2
# 3     2023/02/28 4:07:27 PM GMT+2
# 4     2023/02/28 4:07:27 PM GMT+2
# ..                            ...
# 512  2023/03/03 10:49:58 AM GMT+2
# 513   2023/03/03 1:32:19 PM GMT+2
# 514   2023/03/03 1:32:19 PM GMT+2
# 515   2023/03/03 4:08:20 PM GMT+2
# 516   2023/03/03 4:08:20 PM GMT+2
#
#                    סמן/י את כל המשפטים שרלוונטים אלייך  \
# 0    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 1    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 2    מעקב - לא מצליח לעקוב אחרי התקדמות הרפורמה ומת...
# 3    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# 4    דעה - לא יודע אם אני בעד או נגד הרפורמה;מעקב -...
# ..                                                 ...
# 512  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# 513  פשרה - תומך/ת בפשרה בין המחנות, או אני רוצה לה...
# ...

# %%
px.histogram(new_df, x="var")
# Out:
# <div>                            <div id="444cee9f-6d1c-471d-a66b-0ae00961f2d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("444cee9f-6d1c-471d-a66b-0ae00961f2d7")) {                    Plotly.newPlot(                        "444cee9f-6d1c-471d-a66b-0ae00961f2d7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"var=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["\u05de\u05e2\u05e7\u05d1 - \u05dc\u05d0 \u05de\u05e6\u05dc\u05d9\u05d7 \u05dc\u05e2\u05e7\u05d5\u05d1 \u05d0\u05d7\u05e8\u05d9 \u05d4\u05ea\u05e7\u05d3\u05de\u05d5\u05ea \u05d4\u05e8\u05e4\u05d5\u05e8\u05de\u05d4 \u05d5\u05de\u05ea\
# ...
